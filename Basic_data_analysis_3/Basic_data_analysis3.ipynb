# %% [markdown]
# # Basic Data Analysis - 3

# %% [markdown]
# # **Gotta catch 'em all !**

# %% [markdown]
# ![download.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### 1) Start by importing all important libraries
# For eg, "import numpy as np"

# %%
#your code here
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 2) Read the csv file and assign it to a variable .

# %%
#your code here
dataframe = pd.read_csv('/SA2021_W1_Pokemon.csv')

# %% [markdown]
# ### 3) Display shape of dataframe
# Expected Output - (800, 13)

# %%
#your code here
dataframe.shape
# Out:
# (800, 13)

# %% [markdown]
# ### 4) Print all columns of dataframe
# Return an array containing names of all the columns.

# %%
#your code here
dataframe.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
dataframe.head()
# Out:
#    #                   Name Type 1  ... Speed  Generation  Legendary
# 0  1              Bulbasaur  Grass  ...    45           1      False
# 1  2                Ivysaur  Grass  ...    60           1      False
# 2  3               Venusaur  Grass  ...    80           1      False
# 3  3  VenusaurMega Venusaur  Grass  ...    80           1      False
# 4  4             Charmander   Fire  ...    65           1      False
#
# [5 rows x 13 columns]

# %% [markdown]
# ### 5) Remove the column '#' and update the dataframe.

# %%
#your code here
dataframe = dataframe.drop(['#'], axis=1)

# %% [markdown]
# ### 6) Set the 'Name' column as the index of dataframe

# %%
#your code here
dataframe.set_index('Name')
# Out:
#                         Type 1  Type 2  Total  ...  Speed  Generation  Legendary
# Name                                           ...
# Bulbasaur                Grass  Poison    318  ...     45           1      False
# Ivysaur                  Grass  Poison    405  ...     60           1      False
# Venusaur                 Grass  Poison    525  ...     80           1      False
# VenusaurMega Venusaur    Grass  Poison    625  ...     80           1      False
# Charmander                Fire     NaN    309  ...     65           1      False
# ...                        ...     ...    ...  ...    ...         ...        ...
# Diancie                   Rock   Fairy    600  ...     50           6       True
# DiancieMega Diancie       Rock   Fairy    700  ...    110           6       True
# HoopaHoopa Confined    Psychic   Ghost    600  ...     70           6       True
# HoopaHoopa Unbound     Psychic    Dark    680  ...     80           6       True
# ...

# %% [markdown]
# ###  7) Print a list of all the unique Type-1 powers

# %%
#your code here
dataframe['Type 1'].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %% [markdown]
# ### 8) Create a column which contains the Type 1 and Type 2 abilities of pokemons, seperated with a '+'' sign. Also, display the no. of pokemons that have type-1 power as 'Psychic' and type 2 power as 'Flying' using this new column.

# %%
#your code here
dataframe['Combined']  = dataframe['Type 1'] + '+' + dataframe['Type 2']
x=dataframe[dataframe['Combined'] == 'Psychic+Flying']
len(x)
# Out:
# 6

# %% [markdown]
# ## GRADED Questions (To be answered in the quiz)
# ### Try to retrieve some information from the data and answer the questions below . BEST OF LUCK !!

# %% [markdown]
# ### 1. How many pokemons have 'Mega' in their name?

# %%
#your code here
count=0
for name in dataframe['Name']:
  if 'Mega' in name:
    count+=1
print(count)
# Out:
# 49

# %% [markdown]
# ### 2. What is the standard deviation of Sp. Def. in the dataset ?

# %%
#your code here
dataframe['Sp. Def'].std()
# Out:
# 27.82891579711745

# %% [markdown]
# ### 3. What percentage (upto 3 decimal places) of pokemons are legendary ?

# %%
#your code here
len(dataframe[dataframe['Legendary']== True])
# Out:
# 65

# %%
total_pokemons = dataframe.shape[0]
total_pokemons
# Out:
# 800

# %%
65/800
# Out:
# 0.08125

# %% [markdown]
# ### 4. Name the pokemon(s) with Maximum Defense.

# %%
#your code here
dataframe.sort_values('Defense', ascending=False).head(5)
# Out:
#                     Name Type 1  Type 2  ...  Generation  Legendary      Combined
# 230              Shuckle    Bug    Rock  ...           2      False      Bug+Rock
# 224  SteelixMega Steelix  Steel  Ground  ...           2      False  Steel+Ground
# 333    AggronMega Aggron  Steel     NaN  ...           3      False           NaN
# 223              Steelix  Steel  Ground  ...           2      False  Steel+Ground
# 414             Regirock   Rock     NaN  ...           3       True           NaN
#
# [5 rows x 13 columns]

# %%
dataframe[dataframe['Defense']==230]
# Out:
#                     Name Type 1  Type 2  ...  Generation  Legendary      Combined
# 224  SteelixMega Steelix  Steel  Ground  ...           2      False  Steel+Ground
# 230              Shuckle    Bug    Rock  ...           2      False      Bug+Rock
# 333    AggronMega Aggron  Steel     NaN  ...           3      False           NaN
#
# [3 rows x 13 columns]

# %% [markdown]
# ### 5. Which poison pokemon has the strongest attack ?

# %%
#your code here
dataframe[(dataframe['Type 1']=='Poison') | (dataframe['Type 2']=='Poison')].sort_values('Attack', ascending=False).head(5)
# Out:
#                       Name  Type 1  ... Legendary         Combined
# 19   BeedrillMega Beedrill     Bug  ...     False       Bug+Poison
# 504              Toxicroak  Poison  ...     False  Poison+Fighting
# 96                     Muk  Poison  ...     False              NaN
# 77              Victreebel   Grass  ...     False     Grass+Poison
# 39                Nidoking  Poison  ...     False    Poison+Ground
#
# [5 rows x 13 columns]

# %%
#your code here
plt.figure(figsize=(19,9))
sns.histplot(dataframe['Type 1'])

# %%
#your code here

plt.figure(figsize=(19,9))

sns.histplot(dataframe['Type 2'])

# %%
sns.histplot(dataframe['Defense'])

# %%
sns.distplot(dataframe['Legendary'],dataframe['Generation'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/numpy/lib/histograms.py:905: RuntimeWarning: invalid value encountered in true_divide
#   return n/db/n.sum(), bin_edges

# %%
sns.histplot(dataframe['Generation'])

# %%
#your code here
sns.distplot(dataframe['Generation'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.boxplot(x=dataframe['Generation'])

# %% [markdown]
# ### 7. Which is the second fastest non-legendary 'Ghost' type pokemon from 4th generation ?

# %%
#your code here
c = dataframe[(dataframe['Legendary']==False) & (dataframe['Generation']==4) & ((dataframe['Type 1']=='Ghost') | (dataframe['Type 2']=='Ghost'))]
c.sort_values('Speed', ascending= False)
# Out:
#           Name    Type 1  Type 2  ...  Generation  Legendary        Combined
# 530   Froslass       Ice   Ghost  ...           4      False       Ice+Ghost
# 477  Mismagius     Ghost     NaN  ...           4      False             NaN
# 531      Rotom  Electric   Ghost  ...           4      False  Electric+Ghost
# 473   Drifblim     Ghost  Flying  ...           4      False    Ghost+Flying
# 472   Drifloon     Ghost  Flying  ...           4      False    Ghost+Flying
# 529   Dusknoir     Ghost     NaN  ...           4      False             NaN
# 490  Spiritomb     Ghost    Dark  ...           4      False      Ghost+Dark
#
# [7 rows x 13 columns]

# %% [markdown]
# ### 8. How many non-legendary pokemons have stronger defence but weaker attack than Charizard?

# %%
#your code here
dataframe[dataframe['Name']=='Charizard']
# Out:
#         Name Type 1  Type 2  Total  ...  Speed  Generation  Legendary     Combined
# 6  Charizard   Fire  Flying    534  ...    100           1      False  Fire+Flying
#
# [1 rows x 13 columns]

# %%
dataframe[(dataframe['Legendary']==False) & (dataframe['Attack']<84) & (dataframe['Defense']>78)]
# Out:
#                     Name  Type 1  Type 2  ...  Generation  Legendary       Combined
# 2               Venusaur   Grass  Poison  ...           1      False   Grass+Poison
# 10             Wartortle   Water     NaN  ...           1      False            NaN
# 11             Blastoise   Water     NaN  ...           1      False            NaN
# 23   PidgeotMega Pidgeot  Normal  Flying  ...           1      False  Normal+Flying
# 32             Sandshrew  Ground     NaN  ...           1      False            NaN
# ..                   ...     ...     ...  ...         ...        ...            ...
# 763            Clawitzer   Water     NaN  ...           6      False            NaN
# 773              Carbink    Rock   Fairy  ...           6      False     Rock+Fairy
# 777               Klefki   Steel   Fairy  ...           6      False    Steel+Fairy
# 788             Bergmite     Ice     NaN  ...           6      False            NaN
# ...

# %% [markdown]
# ## *Congratulations on coming this far! Since we were having so much fun playing with this dataset, here are some bonus questions that you can try to further deepen your understanding of the topic!*
#
# ### **Note:** These questions are UNGRADED, and are given as an extra exercise.

# %% [markdown]
# ### Which pokemon has the highest combined value of Attack and Sp. Atk ?

# %%
#your code here
dataframe['Combined attack'] = dataframe['Attack'] + dataframe['Sp. Atk']
dataframe.sort_values('Combined attack', ascending = False). head()
# Out:
#                       Name   Type 1  ...          Combined  Combined attack
# 429     DeoxysAttack Forme  Psychic  ...               NaN              360
# 426  RayquazaMega Rayquaza   Dragon  ...     Dragon+Flying              360
# 163    MewtwoMega Mewtwo X  Psychic  ...  Psychic+Fighting              344
# 164    MewtwoMega Mewtwo Y  Psychic  ...               NaN              344
# 422    KyogrePrimal Kyogre    Water  ...               NaN              330
#
# [5 rows x 14 columns]

# %% [markdown]
# ### Which type of legendary pokemons are the most common?

# %%
#your code here
dataframe[dataframe['Legendary']== True].groupby(['Type 1', 'Type 2']).head()
# Out:
#                          Name    Type 1  ...          Combined  Combined attack
# 156                  Articuno       Ice  ...        Ice+Flying              180
# 157                    Zapdos  Electric  ...   Electric+Flying              215
# 158                   Moltres      Fire  ...       Fire+Flying              225
# 162                    Mewtwo   Psychic  ...               NaN              264
# 163       MewtwoMega Mewtwo X   Psychic  ...  Psychic+Fighting              344
# 164       MewtwoMega Mewtwo Y   Psychic  ...               NaN              344
# 262                    Raikou  Electric  ...               NaN              200
# 263                     Entei      Fire  ...               NaN              205
# 264                   Suicune     Water  ...               NaN              165
# 269                     Lugia   Psychic  ...    Psychic+Flying              180
# 270                     Ho-oh      Fire  ...       Fire+Flying              240
# ...

# %%
plt.figure(figsize=(19,9))
sns.lineplot(dataframe['Type 1'], dataframe['Type 2'], hue = dataframe['Legendary'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.swarmplot(dataframe['Type 1'], hue=dataframe['Legendary'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 35.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ### How many generation-3, non-legendary pokemons have higher HP than the weakest generation-6, legendary pokemon?

# %%
#your code here
dataframe[(dataframe['Legendary']==True) & (dataframe['Generation']==6)].sort_values('HP').head()
# Out:
#                     Name   Type 1  ...       Combined  Combined attack
# 795              Diancie     Rock  ...     Rock+Fairy              200
# 796  DiancieMega Diancie     Rock  ...     Rock+Fairy              320
# 797  HoopaHoopa Confined  Psychic  ...  Psychic+Ghost              260
# 798   HoopaHoopa Unbound  Psychic  ...   Psychic+Dark              330
# 799            Volcanion     Fire  ...     Fire+Water              240
#
# [5 rows x 14 columns]

# %%
dataframe[(dataframe['Legendary']==False) & (dataframe['Generation']==3)].sort_values('HP')
# Out:
#          Name    Type 1 Type 2  ...  Legendary       Combined  Combined attack
# 316  Shedinja       Bug  Ghost  ...      False      Bug+Ghost              120
# 381    Feebas     Water    NaN  ...      False            NaN               25
# 388   Duskull     Ghost    NaN  ...      False            NaN               70
# 303     Ralts   Psychic  Fairy  ...      False  Psychic+Fairy               70
# 323  Nosepass      Rock    NaN  ...      False            NaN               90
# ..        ...       ...    ...  ...        ...            ...              ...
# 400   Walrein       Ice  Water  ...      False      Ice+Water              175
# 350   Wailmer     Water    NaN  ...      False            NaN              140
# 321  Hariyama  Fighting    NaN  ...      False            NaN              160
# 313   Slaking    Normal    NaN  ...      False            NaN              255
# 351   Wailord     Water    NaN  ...      False            NaN              180
#
# [142 rows x 14 columns]

# %% [markdown]
# ### Print out the third slowest pokemon(s) in the dataset.

# %%
#your code here
dataframe.sort_values('Speed').head()
# Out:
#           Name  Type 1 Type 2  ...  Legendary     Combined  Combined attack
# 495   Munchlax  Normal    NaN  ...      False          NaN              125
# 230    Shuckle     Bug   Rock  ...      False     Bug+Rock               20
# 658  Ferroseed   Grass  Steel  ...      False  Grass+Steel               74
# 486     Bonsly    Rock    NaN  ...      False          NaN               90
# 359   Trapinch  Ground    NaN  ...      False          NaN              145
#
# [5 rows x 14 columns]

# %%
dataframe[dataframe['Speed']==15]
# Out:
#            Name  Type 1   Type 2  ...  Legendary       Combined  Combined attack
# 85     Slowpoke   Water  Psychic  ...      False  Water+Psychic              105
# 187      Cleffa   Fairy      NaN  ...      False            NaN               70
# 188   Igglybuff  Normal    Fairy  ...      False   Normal+Fairy               70
# 209      Wooper   Water   Ground  ...      False   Water+Ground               70
# 219      Pineco     Bug      NaN  ...      False            NaN              100
# 289     Silcoon     Bug      NaN  ...      False            NaN               60
# 291     Cascoon     Bug      NaN  ...      False            NaN               60
# 583  Roggenrola    Rock      NaN  ...      False            NaN              100
# 651     Foongus   Grass   Poison  ...      False   Grass+Poison              110
#
# [9 rows x 14 columns]

# %% [markdown]
# ### Which pokemon type has the highest average HP?

# %%
#your code here
dataframe.groupby('Type 1').HP.mean().sort_values()
# Out:
# Type 1
# Bug         56.884058
# Electric    59.795455
# Ghost       64.437500
# Steel       65.222222
# Rock        65.363636
# Dark        66.806452
# Poison      67.250000
# Grass       67.271429
# Fighting    69.851852
# Fire        69.903846
# Psychic     70.631579
# Flying      70.750000
# Ice         72.000000
# Water       72.062500
# Ground      73.781250
# Fairy       74.117647
# Normal      77.275510
# Dragon      83.312500
# Name: HP, dtype: float64

# %%
dataframe.groupby('Type 2').HP.mean().sort_values()
# Out:
# Type 2
# Bug         53.333333
# Poison      58.764706
# Ghost       59.142857
# Grass       62.640000
# Water       62.714286
# Normal      63.500000
# Fairy       64.304348
# Steel       64.636364
# Rock        68.071429
# Fire        71.250000
# Flying      71.391753
# Psychic     72.212121
# Dark        75.550000
# Ground      77.228571
# Fighting    79.461538
# Dragon      82.166667
# Electric    88.166667
# Ice         90.000000
# Name: HP, dtype: float64

# %%
print("Ice")
# Out:
# Ice
